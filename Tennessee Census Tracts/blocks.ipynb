# %%
import geopandas as gpd
import pandas as pd
pd.set_option('display.max_columns', None)
import seaborn as sbn
import matplotlib.pyplot as plt

# %%
url = "/Users/jordanjurinsky/OneDrive - Vanderbilt/commmunityEngagement/Smart Transit_R/Data/Tennessee Census Block/tl_2020_47_tabblock20.shp"
block_shapes = gpd.read_file(url)

# %%
block_shapes.plot()
# Out:
# <AxesSubplot:>
